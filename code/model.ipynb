# %%
import pandas as pd
import seaborn as sns
import missingno as msno
import math
from sklearn.preprocessing import StandardScaler, RobustScaler, MaxAbsScaler, QuantileTransformer
from scipy.stats import gaussian_kde
import scipy.stats as stats
from sklearn.decomposition import PCA
from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Orignal Data AutoML

# %%
#"../dataset/v2_seperate/ecg.csv"
#"../dataset/v2_seperate/fnirs.csv"
#"../dataset/v2_seperate/mec.csv"
#"../dataset/v2_seperate/skin.csv"
#"../dataset/v2_seperate/survey.csv"
#"../dataset/v2_seperate/v2_eda.csv"
#"../dataset/v2_seperate/v2_original.csv"

df = pd.read_csv("../dataset/v2_seperate/mec.csv")
print(df.shape)

df.drop(columns=['No', 'diagnosis'], inplace=True)
df.head(10)
# Out:
# (100, 179)
#    diagnosis_type  ESI_Left  ESI_Right  ECO(%)_Left  ECO(%)_Right  ECI_Left  \
# 0               1      44.0         36        123.0           108       3.4
# 1               1      46.0         39        100.0            83       3.0
# 2               3      38.0         40         97.0            95       3.1
# 3               1      43.0         43        115.0           111       3.1
# 4               1      27.0         34         82.0           109       2.2
# 5               2      34.0         32         99.0            95       3.0
# 6               1      40.0         67        110.0           181       2.9
# 7               3      43.0         44        103.0           103       3.2
# 8               1      38.0         29        103.0            82       2.7
# 9               1      37.0         38        103.0           106       3.0
#
#    ECI_Right  ECR_Left  ECR_Right  RAI_Left  ...  W_Area_R_Right  \
# 0        3.0    1523.0       1391      89.4  ...         214.847
# 1        2.5    1804.0       2092      92.8  ...             NaN
# 2        3.1    1300.0       1251      87.6  ...         603.584
# 3        3.0    1433.0       1582      95.7  ...         480.577
# 4        2.9    2064.0       1678      75.5  ...         438.582
# 5        2.9    1237.0       1255      71.0  ...             NaN
# 6        4.8    1488.0        969      95.3  ...         114.996
# 7        3.2    2196.0       1678      77.4  ...         651.015
# 8        2.1    1936.0       2399      87.0  ...        -385.804
# 9        3.1    1450.0       1600      74.5  ...         387.005
#
#    Sys_rate_R_Right  H4/H1_R_Right  Wfb_ratio_R_Right  meanSys_area_R_Right  \
# 0              0.45           0.47             2.2849              1246.534
# 1               NaN            NaN                NaN                   NaN
# 2              0.45           0.50             1.9694              3091.302
# 3              0.40           0.56             1.7614              2715.069
# 4              0.48           0.52             2.1558              2131.714
# 5               NaN            NaN                NaN                   NaN
# 6              0.32           0.50             4.0013               510.026
# 7              0.44           0.52             1.6465              3031.565
# 8              0.32           0.62            19.2505              1901.035
# 9              0.50           0.34             1.7619              2372.938
#
#    medSys_area_R_Right  meanPulseArea_R_Right  medPulseArea_R_Right  \
# 0             1294.731            1818.141674              1767.252
# 1                  NaN                    NaN                   NaN
# 2             3131.550            4390.967337              4455.811
# 3             2592.869            4499.700647              4504.887
# 4             2216.248            2887.613241              3028.136
# 5                  NaN                    NaN                   NaN
# 6              461.830            1354.329066              1596.307
# 7             3238.129            4258.831053              4652.240
# 8             1826.291            5540.169444              6572.131
# 9             2464.713            3093.280135              3137.107
#
#    meanPulseWidth_R_Right  medPulseWidth_R_Right
# 0                 967.548               1147.687
# 1                     NaN                    NaN
# 2                2248.437               2271.170
# 3                1938.826               2098.553
# 4                1384.499               1466.942
# 5                     NaN                    NaN
# 6                 352.571                320.504
# 7                1859.749               1726.041
# 8                1064.208               1097.796
# 9                2048.291               2055.060
#
# [10 rows x 177 columns]

# %%
from pycaret.classification import *

# PyCaret 설정
clf = setup(data=df, target='diagnosis_type', session_id=1557)

compare_models()
results = pull()
best_f1 = results['F1'].max()

print("Best F1 Score:", best_f1)
# Out:
# <style type="text/css">
# #T_69a24_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_69a24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69a24_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_69a24_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69a24_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69a24_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_69a24_row0_col1" class="data row0 col1" >1557</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69a24_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_69a24_row1_col1" class="data row1 col1" >diagnosis_type</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69a24_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_69a24_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69a24_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_69a24_row3_col1" class="data row3 col1" >1: 0, 2: 1, 3: 2</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_69a24_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_69a24_row4_col1" class="data row4 col1" >(100, 177)</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_69a24_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_69a24_row5_col1" class="data row5 col1" >(100, 177)</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_69a24_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_69a24_row6_col1" class="data row6 col1" >(70, 177)</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_69a24_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_69a24_row7_col1" class="data row7 col1" >(30, 177)</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_69a24_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_69a24_row8_col1" class="data row8 col1" >176</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_69a24_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_69a24_row9_col1" class="data row9 col1" >14.0%</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_69a24_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_69a24_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_69a24_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_69a24_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_69a24_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_69a24_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_69a24_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_69a24_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_69a24_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_69a24_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_69a24_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_69a24_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_69a24_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_69a24_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_69a24_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_69a24_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_69a24_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_69a24_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_69a24_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_69a24_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_69a24_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_69a24_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_69a24_row20_col1" class="data row20 col1" >275c</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6880a th {
#   text-align: left;
# }
# #T_6880a_row0_col0, #T_6880a_row0_col4, #T_6880a_row0_col5, #T_6880a_row1_col0, #T_6880a_row1_col4, #T_6880a_row1_col6, #T_6880a_row1_col7, #T_6880a_row2_col0, #T_6880a_row2_col4, #T_6880a_row2_col5, #T_6880a_row2_col6, #T_6880a_row2_col7, #T_6880a_row3_col0, #T_6880a_row3_col4, #T_6880a_row3_col5, #T_6880a_row3_col6, #T_6880a_row3_col7, #T_6880a_row4_col0, #T_6880a_row4_col1, #T_6880a_row4_col3, #T_6880a_row4_col5, #T_6880a_row4_col6, #T_6880a_row4_col7, #T_6880a_row5_col0, #T_6880a_row5_col1, #T_6880a_row5_col3, #T_6880a_row5_col4, #T_6880a_row5_col5, #T_6880a_row5_col6, #T_6880a_row5_col7, #T_6880a_row6_col0, #T_6880a_row6_col1, #T_6880a_row6_col3, #T_6880a_row6_col4, #T_6880a_row6_col5, #T_6880a_row6_col6, #T_6880a_row6_col7, #T_6880a_row7_col0, #T_6880a_row7_col1, #T_6880a_row7_col3, #T_6880a_row7_col4, #T_6880a_row7_col5, #T_6880a_row7_col6, #T_6880a_row7_col7, #T_6880a_row8_col0, #T_6880a_row8_col1, #T_6880a_row8_col3, #T_6880a_row8_col4, #T_6880a_row8_col5, #T_6880a_row8_col6, #T_6880a_row8_col7, #T_6880a_row9_col0, #T_6880a_row9_col1, #T_6880a_row9_col3, #T_6880a_row9_col4, #T_6880a_row9_col5, #T_6880a_row9_col6, #T_6880a_row9_col7, #T_6880a_row10_col0, #T_6880a_row10_col1, #T_6880a_row10_col3, #T_6880a_row10_col4, #T_6880a_row10_col5, #T_6880a_row10_col6, #T_6880a_row10_col7, #T_6880a_row11_col0, #T_6880a_row11_col1, #T_6880a_row11_col3, #T_6880a_row11_col4, #T_6880a_row11_col5, #T_6880a_row11_col6, #T_6880a_row11_col7, #T_6880a_row12_col0, #T_6880a_row12_col1, #T_6880a_row12_col3, #T_6880a_row12_col4, #T_6880a_row12_col5, #T_6880a_row12_col6, #T_6880a_row12_col7, #T_6880a_row13_col0, #T_6880a_row13_col1, #T_6880a_row13_col3, #T_6880a_row13_col4, #T_6880a_row13_col5, #T_6880a_row13_col6, #T_6880a_row13_col7, #T_6880a_row14_col0, #T_6880a_row14_col1, #T_6880a_row14_col3, #T_6880a_row14_col4, #T_6880a_row14_col5, #T_6880a_row14_col6, #T_6880a_row14_col7, #T_6880a_row15_col0, #T_6880a_row15_col1, #T_6880a_row15_col3, #T_6880a_row15_col4, #T_6880a_row15_col5, #T_6880a_row15_col6, #T_6880a_row15_col7 {
#   text-align: left;
# }
# #T_6880a_row0_col1, #T_6880a_row0_col2, #T_6880a_row0_col3, #T_6880a_row0_col6, #T_6880a_row0_col7, #T_6880a_row1_col1, #T_6880a_row1_col2, #T_6880a_row1_col3, #T_6880a_row1_col5, #T_6880a_row2_col1, #T_6880a_row2_col2, #T_6880a_row2_col3, #T_6880a_row3_col1, #T_6880a_row3_col2, #T_6880a_row3_col3, #T_6880a_row4_col2, #T_6880a_row4_col4, #T_6880a_row5_col2, #T_6880a_row6_col2, #T_6880a_row7_col2, #T_6880a_row8_col2, #T_6880a_row9_col2, #T_6880a_row10_col2, #T_6880a_row11_col2, #T_6880a_row12_col2, #T_6880a_row13_col2, #T_6880a_row14_col2, #T_6880a_row15_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6880a_row0_col8, #T_6880a_row1_col8, #T_6880a_row2_col8, #T_6880a_row4_col8, #T_6880a_row5_col8, #T_6880a_row6_col8, #T_6880a_row7_col8, #T_6880a_row8_col8, #T_6880a_row9_col8, #T_6880a_row10_col8, #T_6880a_row11_col8, #T_6880a_row12_col8, #T_6880a_row13_col8, #T_6880a_row14_col8, #T_6880a_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6880a_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6880a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6880a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6880a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6880a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6880a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6880a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6880a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6880a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6880a_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_6880a_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6880a_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_6880a_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_6880a_row0_col1" class="data row0 col1" >0.5143</td>
#       <td id="T_6880a_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_6880a_row0_col3" class="data row0 col3" >0.5143</td>
#       <td id="T_6880a_row0_col4" class="data row0 col4" >0.4272</td>
#       <td id="T_6880a_row0_col5" class="data row0 col5" >0.4470</td>
#       <td id="T_6880a_row0_col6" class="data row0 col6" >0.1349</td>
#       <td id="T_6880a_row0_col7" class="data row0 col7" >0.1692</td>
#       <td id="T_6880a_row0_col8" class="data row0 col8" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_6880a_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_6880a_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_6880a_row1_col1" class="data row1 col1" >0.5143</td>
#       <td id="T_6880a_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_6880a_row1_col3" class="data row1 col3" >0.5143</td>
#       <td id="T_6880a_row1_col4" class="data row1 col4" >0.4524</td>
#       <td id="T_6880a_row1_col5" class="data row1 col5" >0.4558</td>
#       <td id="T_6880a_row1_col6" class="data row1 col6" >0.1178</td>
#       <td id="T_6880a_row1_col7" class="data row1 col7" >0.1364</td>
#       <td id="T_6880a_row1_col8" class="data row1 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_6880a_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_6880a_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_6880a_row2_col1" class="data row2 col1" >0.5143</td>
#       <td id="T_6880a_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_6880a_row2_col3" class="data row2 col3" >0.5143</td>
#       <td id="T_6880a_row2_col4" class="data row2 col4" >0.4267</td>
#       <td id="T_6880a_row2_col5" class="data row2 col5" >0.4309</td>
#       <td id="T_6880a_row2_col6" class="data row2 col6" >0.0592</td>
#       <td id="T_6880a_row2_col7" class="data row2 col7" >0.0803</td>
#       <td id="T_6880a_row2_col8" class="data row2 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_6880a_level0_row3" class="row_heading level0 row3" >dummy</th>
#       <td id="T_6880a_row3_col0" class="data row3 col0" >Dummy Classifier</td>
#       <td id="T_6880a_row3_col1" class="data row3 col1" >0.5143</td>
#       <td id="T_6880a_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_6880a_row3_col3" class="data row3 col3" >0.5143</td>
#       <td id="T_6880a_row3_col4" class="data row3 col4" >0.2694</td>
#       <td id="T_6880a_row3_col5" class="data row3 col5" >0.3522</td>
#       <td id="T_6880a_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_6880a_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_6880a_row3_col8" class="data row3 col8" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_6880a_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_6880a_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6880a_row4_col1" class="data row4 col1" >0.4857</td>
#       <td id="T_6880a_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_6880a_row4_col3" class="data row4 col3" >0.4857</td>
#       <td id="T_6880a_row4_col4" class="data row4 col4" >0.4924</td>
#       <td id="T_6880a_row4_col5" class="data row4 col5" >0.4384</td>
#       <td id="T_6880a_row4_col6" class="data row4 col6" >0.0841</td>
#       <td id="T_6880a_row4_col7" class="data row4 col7" >0.1253</td>
#       <td id="T_6880a_row4_col8" class="data row4 col8" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_6880a_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_6880a_row5_col0" class="data row5 col0" >CatBoost Classifier</td>
#       <td id="T_6880a_row5_col1" class="data row5 col1" >0.4857</td>
#       <td id="T_6880a_row5_col2" class="data ro
# Best F1 Score: 0.4558
# Model with best F1 Score:
# Model       Ada Boost Classifier
# Accuracy                  0.5143
# AUC                          0.0
# Recall                    0.5143
# Prec.                     0.4524
# F1                        0.4558
# Kappa                     0.1178
# MCC                       0.1364
# TT (Sec)                   0.016
# Name: ada, dtype: object

# %%
models
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
evaluate_model(models)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
